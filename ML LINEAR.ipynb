# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Datasets\Housingprices')

# %%
data.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
# 5  7237550310         14 May 2017   1230000.0               4
# 6  1321400060        14 June 2017    257500.0               3
# 7  2008000270     15 January 2016    291850.0               3
# 8  2414600126       15 April 2016    229500.0               3
# 9  3793500160       15 March 2016    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %% [markdown]
# # DATA EXPLORATION AND PREPROCESSING FOR DEP VAR(LABELS)

# %%
data['Sale Price'].head(10)
# Out:
# 0     221900.0
# 1     538000.0
# 2     180000.0
# 3     604000.0
# 4     510000.0
# 5    1230000.0
# 6     257500.0
# 7     291850.0
# 8     229500.0
# 9     323000.0
# Name: Sale Price, dtype: float64

# %%
data['Sale Price'].tail(10)
# Out:
# 21603     507250.0
# 21604     429000.0
# 21605     610685.0
# 21606    1010000.0
# 21607     475000.0
# 21608     360000.0
# 21609     400000.0
# 21610     402101.0
# 21611     400000.0
# 21612     325000.0
# Name: Sale Price, dtype: float64

# %%
data['Sale Price'].shape
# Out:
# (21613,)

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
#OUTLIERS
plt.scatter(x=data['ID'],y=data['Sale Price'])

# %%
import seaborn as sns
sns.boxplot(x=data['Sale Price'])
# Out:
# <AxesSubplot:xlabel='Sale Price'>

# %%
q1=data['Sale Price'].quantile(0.25)
q3=data['Sale Price'].quantile(0.75)
iqr=q3-q1
iqr
# Out:
# 323050.0

# %%
lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr
lower_limit,upper_limit
# Out:
# (-162625.0, 1129575.0)

# %%
#imputing the outliers by its limit value
def limit_imputer(value):
    if value<lower_limit:
        return lower_limit
    if value>upper_limit:
        return upper_limit
    else:
        return value

# %%
data['Sale Price']=data['Sale Price'].apply(limit_imputer)

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
data.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# No of Times Visited                          0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# ...

# %%
#for whole data set
data[data.isnull().any(axis=1)]
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 90     2791500270         14 May 2017         NaN               4
# 168    3261020370        14 June 2017         NaN               3
# 226    8682281200       15 March 2016    479950.0               2
# 249    3797001895       15 April 2016    481000.0               3
# 275    4215100060       15 March 2016    365000.0               3
# 296    5468730030      14 August 2017    265000.0               3
# 321    2597650240     14 October 2017    520000.0               3
# 352     616000140     15 January 2016    315000.0               3
# 372    2231500030       15 March 2016    530000.0               4
# 402    6021501685       15 April 2016    352000.0               2
# 438    9528102772        14 July 2017    438000.0               2
# 449    4140090240    14 November 2017    520000.0               3
# 483    9169600135     14 October 2017    525000.0               3
# ...

# %%
#Missing values
data.dropna(inplace=True,axis=0,subset=['Sale Price'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
#Histogram
plt.hist(data['Sale Price'],bins=10,color='green')
plt.xlabel('Intervals')
plt.ylabel('Selling Price')
plt.title('Histogram of selling price')
plt.show()

# %% [markdown]
# # DATA EXPLORATION AND PREPROCESSING FOR INDEP VAR'S(FEATURES)

# %%
num_columns=['No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)',
            'Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='median')
data[num_columns]=imputer.fit_transform(data[num_columns])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
data['Zipcode'].shape #it should convert into 2D array
# Out:
# (21609,)

# %%
column=data['Zipcode'].values.reshape(-1,1)
column.shape
# Out:
# (21609, 1)

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
data['Zipcode']=imputer.fit_transform(column)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %% [markdown]
# # VARIABLE TRANSFORMATION

# %%
data['Zipcode']=data['Zipcode'].astype('object')

# %%
data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                       object
# Latitude                                     float64
# ...

# %%
data['No of Times Visited'].unique()
# Out:
# array(['None', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
mapping={'None':'0',
        'Once':'1',
        'Twice':'2',
        'Thrice':'3',
        'Four':'4'}
data['No of Times Visited']=data['No of Times Visited'].map(mapping)
data['No of Times Visited'].unique()
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
data['Ever Renovated']=np.where(data['Renovated Year']==0,'No','Yes')

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                   0  ...
# 1              No                   0  ...
# ...

# %%
data['Purchase Year']=pd.DatetimeIndex(data['Date House was Sold']).year

# %%
data['Years since renovation']=np.where(data['Ever Renovated']=='Yes',
                                       abs(data['Purchase Year']-data['Renovated Year']),0)

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Age of House (in Years)  \
# 0              No                   0  ...                      63
# ...

# %%
#drop the variables wich are not useful
data.drop(columns=['Renovated Year','Date House was Sold','Purchase Year'],inplace=True)
data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %%
#data.to_csv('Transformed_data',index=False)

# %%
data['Sale Price'].corr(data['Flat Area (in Sqft)'])
# Out:
# 0.6951704258420669

# %%
np.corrcoef(data['Sale Price'],data['Flat Area (in Sqft)'])
# Out:
# array([[1.        , 0.69517043],
#        [0.69517043, 1.        ]])

# %%
data.drop(columns=['ID']).corr()
# Out:
#                                            Sale Price  No of Bedrooms  \
# Sale Price                                   1.000000        0.339407
# No of Bedrooms                               0.339407        1.000000
# No of Bathrooms                              0.535124        0.515813
# Flat Area (in Sqft)                          0.695170        0.576628
# Lot Area (in Sqft)                           0.101319        0.031692
# No of Floors                                 0.298913        0.175536
# Overall Grade                                0.680914        0.349223
# Area of the House from Basement (in Sqft)    0.606527        0.477549
# Basement Area (in Sqft)                      0.307513        0.303294
# Age of House (in Years)                     -0.064306       -0.154113
# Latitude                                     0.402430       -0.008708
# Longitude                                    0.045401        0.129569
# ...

# %%
data['Flat Area (in Sqft)'].corr(data['Sale Price'])
# Out:
# 0.6951704258420668

# %%
data.drop(['ID'],axis=1).corr()
# Out:
#                                            Sale Price  No of Bedrooms  \
# Sale Price                                   1.000000        0.339407
# No of Bedrooms                               0.339407        1.000000
# No of Bathrooms                              0.535124        0.515813
# Flat Area (in Sqft)                          0.695170        0.576628
# Lot Area (in Sqft)                           0.101319        0.031692
# No of Floors                                 0.298913        0.175536
# Overall Grade                                0.680914        0.349223
# Area of the House from Basement (in Sqft)    0.606527        0.477549
# Basement Area (in Sqft)                      0.307513        0.303294
# Age of House (in Years)                     -0.064306       -0.154113
# Latitude                                     0.402430       -0.008708
# Longitude                                    0.045401        0.129569
# ...

# %% [markdown]
# # Exploring catagorical variable

# %%
data.drop(columns='ID',inplace=True)

# %%
data['Condition of the House'].head(10)
# Out:
# 0         Fair
# 1         Fair
# 2         Fair
# 3    Excellent
# 4         Fair
# 5         Fair
# 6         Fair
# 7         Fair
# 8         Fair
# 9         Fair
# Name: Condition of the House, dtype: object

# %%
data['Condition of the House'].value_counts()
# Out:
# Fair         14028
# Good          5678
# Excellent     1701
# Okay           172
# Bad             30
# Name: Condition of the House, dtype: int64

# %%
data.groupby('Condition of the House')['Sale Price'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Condition of the House'>

# %%
data.groupby('Condition of the House')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Condition of the House'>

# %%
data.groupby('Waterfront View')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Waterfront View'>

# %%
data.groupby('Ever Renovated')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Ever Renovated'>

# %%
data.groupby('Zipcode')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Zipcode'>

# %% [markdown]
# # ANOVA

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
data=data.rename(columns={'Sale Price':'Sale_Price'})

# %%
data=data.rename(columns={'Condition of the House':'Condition_of_the_House'})

# %%
data=data.rename(columns={'Ever Renovated':'Ever_Renovated'})

# %%
data=data.rename(columns={'Waterfront View':'Waterfront_View'})

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront_View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#   Condition_of_the_House  Overall Grade  \
# 0                   Fair              7
# ...

# %%
mod=ols('Sale_Price~Condition_of_the_House',data=data).fit()

# %%
#creating anova table using stats library
Anova_Table=sm.stats.anova_lm(mod,typ=2) #one way

# %%
print(Anova_Table)
# Out:
#                               sum_sq       df         F        PR(>F)
# Condition_of_the_House  1.441831e+13      4.0  58.25563  5.447605e-49
# Residual                1.336752e+15  21604.0       NaN           NaN

# %% [markdown]
# hence F value is greater and p is <0.05,hence it rejects null hypothesis

# %%
mod=ols('Sale_Price~Waterfront_View',data=data).fit()
Anova_Table=sm.stats.anova_lm(mod,typ=2) #typ=2,diff types of sum of squrares
print(Anova_Table)
# Out:
#                        sum_sq       df           F         PR(>F)
# Waterfront_View  3.283737e+13      1.0  538.192683  1.275558e-117
# Residual         1.318333e+15  21607.0         NaN            NaN

# %%
mod=ols('Sale_Price~Ever_Renovated',data=data).fit()
sm.stats.anova_lm(mod,typ=2)
# Out:
#                       sum_sq       df           F        PR(>F)
# Ever_Renovated  1.998463e+13      1.0  324.378469  5.419055e-72
# Residual        1.331185e+15  21607.0         NaN           NaN

# %%
mod=ols('Sale_Price ~ Zipcode',data=data).fit()
sm.stats.anova_lm(mod,typ=2)
# Out:
#                 sum_sq       df           F  PR(>F)
# Zipcode   6.859657e+14     69.0  321.902033     0.0
# Residual  6.652044e+14  21539.0         NaN     NaN

# %%
#creating dummy variables for categorical
data=pd.get_dummies(data,columns=['Condition_of_the_House'],drop_first=True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront_View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  Latitude  \
# ...

# %%
data=pd.get_dummies(data,columns=['Ever_Renovated','Waterfront_View'],drop_first=True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                   0              7
# 1              7242.0           2.0                   0              7
# 2             10000.0           1.0                   0              6
# 3              5000.0           1.0                   0              7
# 4              8080.0           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %% [markdown]
# # Binning

# %%
zip_table=data.groupby('Zipcode').agg({'Sale_Price':'mean'}).sort_values('Sale_Price',ascending=True)

# %%
zip_table.head()
# Out:
#             Sale_Price
# Zipcode
# 98002.0  234284.035176
# 98168.0  240328.371747
# 98032.0  251296.240000
# 98001.0  280804.690608
# 98148.0  284908.596491

# %%
zip_table['zip_group']=pd.cut(zip_table['Sale_Price'],bins=10,labels=['Zipcode_group_0',
                                                                     'Zipcode_group_1',
                                                                     'Zipcode_group_2',
                                                                     'Zipcode_group_3',
                                                                     'Zipcode_group_4',
                                                                     'Zipcode_group_5',
                                                                     'Zipcode_group_6',
                                                                     'Zipcode_group_7',
                                                                     'Zipcode_group_8',
                                                                     'Zipcode_group_9'],include_lowest=True)

# %%
zip_table=zip_table.drop(columns=['Sale_Price'])

# %%
data=pd.merge(data,zip_table,left_on='Zipcode',how='left',right_index=True)

# %%
data=data.drop(columns='Zipcode')

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                   0              7
# 1              7242.0           2.0                   0              7
# 2             10000.0           1.0                   0              6
# 3              5000.0           1.0                   0              7
# 4              8080.0           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
data=pd.get_dummies(data,columns=['zip_group'],drop_first=True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                   0              7
# 1              7242.0           2.0                   0              7
# 2             10000.0           1.0                   0              6
# 3              5000.0           1.0                   0              7
# 4              8080.0           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %% [markdown]
# # SPLITTING DATA

# %%
Y=data.iloc[:,0]

# %%
X=data.iloc[:,1:31]

# %%
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0               3             1.00               1180.0              5650.0
# 1               3             2.25               2570.0              7242.0
# 2               2             1.00                770.0             10000.0
# 3               4             3.00               1960.0              5000.0
# 4               3             2.00               1680.0              8080.0
#
#    No of Floors No of Times Visited  Overall Grade  \
# 0           1.0                   0              7
# 1           2.0                   0              7
# 2           1.0                   0              6
# 3           1.0                   0              7
# 4           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train.shape
# Out:
# (15126, 30)

# %%
X_test.shape
# Out:
# (6483, 30)

# %%
Y_train.shape
# Out:
# (15126,)

# %%
Y_test.shape
# Out:
# (6483,)

# %% [markdown]
# # FEATURE SCALING-STANDARDISATION

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()

# %%
X_train=sd.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.41204451, -0.47431693, -0.31646842, ..., -0.11308736,
#         -0.16733363, -0.04457893],
#        [-0.41204451, -1.45066319, -0.79403226, ..., -0.11308736,
#         -0.16733363, -0.04457893],
#        [-0.41204451, -1.45066319, -0.91342322, ..., -0.11308736,
#         -0.16733363, -0.04457893],
#        ...,
#        [ 1.80872345,  1.15292685,  2.27757153, ..., -0.11308736,
#         -0.16733363, -0.04457893],
#        [ 0.69833947,  0.8274781 ,  1.37671247, ..., -0.11308736,
#         -0.16733363, -0.04457893],
#        [ 0.69833947,  0.50202934,  0.13938797, ..., -0.11308736,
#         -0.16733363, -0.04457893]])

# %%
X_test=sd.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-0.37193524,  0.49639808,  1.40918364, ..., -0.11035391,
#         -0.17234093, -0.05562857],
#        [ 0.63317362,  1.78753098,  2.02373221, ..., -0.11035391,
#         -0.17234093, -0.05562857],
#        [ 0.63317362,  0.49639808,  0.54223119, ..., -0.11035391,
#         -0.17234093, -0.05562857],
#        ...,
#        [-0.37193524, -0.79473482, -0.58809922, ..., -0.11035391,
#         -0.17234093, -0.05562857],
#        [ 2.64339135,  2.1103142 ,  1.189702  , ..., -0.11035391,
#         -0.17234093, -0.05562857],
#        [-0.37193524, -1.44030127, -1.10388106, ..., -0.11035391,
#         -0.17234093, -0.05562857]])

# %% [markdown]
# # Basic Predictive model with mean regression

# %%
df=pd.read_csv('Datasets\Transformed_Housing_Data2.csv')
df.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
df['mean_sales']=df['Sale_Price'].mean()
df['mean_sales'].head()
# Out:
# 0    511618.558147
# 1    511618.558147
# 2    511618.558147
# 3    511618.558147
# 4    511618.558147
# Name: mean_sales, dtype: float64

# %%
plt.figure(dpi=100)
k=range(0,len(data))
plt.scatter(k,df["Sale_Price"].sort_values(),color='red',label='Actual sale price')
plt.plot(k,df['mean_sales'].sort_values(),color='green',label='mean-price')
plt.xlabel('Fitting points(Ascending)')
plt.ylabel("Sale Price")
plt.title("Over all Mean")
plt.legend()

# %%
#avg sle price w.r.t to overall grade
grades_mean=df.pivot_table(values='Sale_Price',columns='Overall Grade',aggfunc=np.mean)
grades_mean
# Out:
# Overall Grade        1          2              3              4   \
# Sale_Price     142000.0  1129575.0  205666.666667  214381.034483
#
# Overall Grade             5             6              7              8   \
# Sale_Price     248523.971074  301882.01472  402239.619779  537584.082097
#
# Overall Grade             9              10
# Sale_Price     736936.769025  960408.078866

# %%
#making  new column
df['grade_mean']=0
for i in grades_mean.columns:
    df['grade_mean'][df['Overall Grade']==i]=grades_mean[i][0]
df['grade_mean'].head()
# Out:
# <ipython-input-97-902c28d565c8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['grade_mean'][df['Overall Grade']==i]=grades_mean[i][0]
# <ipython-input-97-902c28d565c8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['grade_mean'][df['Overall Grade']==i]=grades_mean[i][0]
# 0    402239.619779
# 1    402239.619779
# 2    301882.014720
# 3    402239.619779
# 4    537584.082097
# Name: grade_mean, dtype: float64

# %%
grad_wise_list=[]
for i in range(1,11):
    k=data['Sale_Price'][data['Overall Grade']==i]
grad_wise_list.append(k)

# %%
#prediction-actual=residual
mean_diff=df['mean_sales']-df['Sale_Price']
grade_mean_diff=df['grade_mean']-df['Sale_Price']

# %%
#RESIDUAL PLOT
k=range(0,len(df))
l=[0 for i in range(len(df))] #for 0 residuals
plt.figure(figsize=(15,6),dpi=100)
plt.subplot(1,2,1)
plt.scatter(k,mean_diff,color='red',label='Residuals',s=2)
plt.plot(k,l,color='green',label='mean regression',linewidth=3)
plt.xlabel('Fitted points')
plt.ylabel('Residuals')
plt.title("Residuals with respect to overall Mean")

plt.subplot(1,2,2)
plt.scatter(k,grade_mean_diff,color='red',label='Residuals',s=2)
plt.plot(k,l,color='green',label='mean regression',linewidth=3)
plt.xlabel('Fitted points')
plt.ylabel('Residuals')
plt.legend()
plt.title("Residuals with respect to Gradewise Mean")
plt.legend()

# %%
#Evaluation metrices
#mean error
cost=sum(mean_diff)/len(df)
print(round(cost,7))
# Out:
# 0.0

# %% [markdown]
# we are getting 0 error as our model is perfect,but its no true because we already know mean diff model is not performing well
# even its giving 0 error because when we add up errors there might be some + and- errors when we add up they cancel each other
# so we get mean error as 0 ,to overcome this we have MAE

# %%
#MSE
y=df['Sale_Price']
y_hat1=df['mean_sales']
y_hat2=df['grade_mean']
n=len(df)

len(y),len(y_hat1),len(y_hat2),n
# Out:
# (21609, 21609, 21609, 21609)

# %%
#MAE
cost_mean=sum(abs(y_hat1-y))/n
cost_mean
# Out:
# 199168.78146839526

# %%
cost_grade_mean=sum(abs(y_hat2-y))/n
cost_grade_mean
# Out:
# 137081.70298203363

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_hat2,y)
# Out:
# 137081.7029820291

# %%
#MSE
from sklearn.metrics import mean_squared_error
mean_squared_error(y_hat1,y),mean_squared_error(y_hat2,y)
# Out:
# (62528116847.799576, 30804835720.342426)

# %%
#RMSE
from sklearn.metrics import mean_squared_error
mean_squared_error(y_hat1,y)**0.5,mean_squared_error(y_hat2,y)**0.5
# Out:
# (250056.2273725643, 175513.06424406826)

# %% [markdown]
# RMSE>MAS ,but still RMSE is in the same overall scale as the MAS

# %%
y=df['Sale_Price']
y_bar=df['mean_sales']
y_hat=df['grade_mean']
n=len(df)

len(y),len(y_hat1),len(y_hat2),n
# Out:
# (21609, 21609, 21609, 21609)

# %%
mse_mean=mean_squared_error(y_bar,y)
mse_mean
# Out:
# 62528116847.799576

# %%
mse_model=mean_squared_error(y_hat,y)
mse_model
# Out:
# 30804835720.342426

# %%
R2=1-(mse_model)/(mse_mean)
R2
# Out:
# 0.5073442592981836

# %%
#mean reg model
sale_price=df['Sale_Price'].head(30)
flat_area=df['Flat Area (in Sqft)'].head(30)
small_data=pd.DataFrame({'sale_price':sale_price,'flat_area':flat_area})
small_data
# Out:
#     sale_price  flat_area
# 0     221900.0     1180.0
# 1     538000.0     2570.0
# 2     180000.0      770.0
# 3     604000.0     1960.0
# 4     510000.0     1680.0
# 5    1129575.0     5420.0
# 6     257500.0     1715.0
# 7     291850.0     1060.0
# 8     229500.0     1780.0
# 9     323000.0     1890.0
# 10    662500.0     3560.0
# 11    468000.0     1160.0
# 12    310000.0     1430.0
# 13    400000.0     1370.0
# 14    530000.0     1810.0
# 15    650000.0     2950.0
# 16    395000.0     1890.0
# 17    485000.0     1600.0
# 18    189000.0     1200.0
# 19    230000.0     1250.0
# 20    385000.0     1620.0
# 21   1129575.0     3050.0
# 22    285000.0     2270.0
# 23    252700.0     1070.0
# 24    329000.0     2450.0
# 25    233000.0     1710.0
# 26    937000.0     2450.0
# 27    667000.0     1400.0
# 28    438000.0     1520.0
# 29    719000.0     2570.0

# %%
plt.figure(dpi=100)
plt.scatter(small_data['flat_area'],small_data['sale_price'],color='red')
plt.xlabel('flat area')
plt.ylabel('sale price')
plt.title('sale price-flat area')
plt.show()

# %%
small_data['mean_price']=small_data.sale_price.mean()

plt.figure(dpi=100)
plt.scatter(small_data.flat_area,small_data.sale_price,color='red')
plt.plot(small_data.flat_area,small_data.mean_price,color='yellow',label='Mean sale price')
plt.xlabel('flat area')
plt.ylabel('sale price')
plt.title('sale price-flat area')
plt.legend()
plt.show()

# %% [markdown]
# # LINEAR REGRESSION

# %%
c=0
m=0
line=[] #to store the computed values of y
from sklearn.metrics import mean_squared_error as mse
for i in range(len(small_data)):
    line.append(small_data.flat_area[i]*m+c)
plt.figure(dpi=100)
plt.scatter(small_data.flat_area,small_data.sale_price)
plt.plot(small_data.flat_area,line,label='m=0.0; c=0')
plt.xlabel('flat area')
plt.ylabel('sale area')
MSE=mse(small_data.sale_price,line)
plt.title('slope'+str(m)+'with mse'+str(MSE))
# Out:
# Text(0.5, 1.0, 'slope0with mse281372081125.0')

# %%
c=0
m=50
line=[] #to store the computed values of y
from sklearn.metrics import mean_squared_error as mse
for i in range(len(small_data)):
    line.append(small_data.flat_area[i]*m+c)
plt.figure(dpi=100)
plt.scatter(small_data.flat_area,small_data.sale_price)
plt.plot(small_data.flat_area,line,label='m=0.0; c=0')
plt.xlabel('flat area')
plt.ylabel('sale area')
MSE=mse(small_data.sale_price,line)
plt.title('slope'+str(m)+'with mse'+str(MSE))
# Out:
# Text(0.5, 1.0, 'slope50with mse184728400708.33334')

# %%
def slope_error(slope,intercept,small_data):
    sale=[]
    for i in range(len(small_data)):
        tmp=small_data.flat_area[i]*slope+intercept
        sale.append(tmp)
    MSE=mse(small_data.sale_price,sale)
    return MSE

# %%
slope=[i/10 for i in range(0,5000)]
Cost=[]
for i in slope:
    cost=slope_error(slope=i,intercept=0,small_data=small_data)
    Cost.append(cost)

# %%
#Arranging in dataframe
Cost_table=pd.DataFrame({'slope':slope,'cost':Cost})
Cost_table.tail()
# Out:
#       slope          cost
# 4995  499.5  3.526038e+11
# 4996  499.6  3.528488e+11
# 4997  499.7  3.530938e+11
# 4998  499.8  3.533389e+11
# 4999  499.9  3.535842e+11

# %%
#plotting the cost values coresponding to every value of Beta
plt.plot(Cost_table.slope,Cost_table.cost,label='cost function curve')
plt.xlabel('value of cost')
plt.ylabel('Cost')
plt.legend()
#cost fun curve or loss fun curve

# %%
def intercept_error(slope,intercept,small_data):
    sale=[]
    for i in range(len(small_data.flat_area)):
        tmp=small_data.flat_area[i]*slope+intercept
        sale.append(tmp)
    MSE=mse(small_data.sale_price,sale)
    return MSE

# %%
intercept=[i for i in range(5000,50000)]
Cost=[]
for i in intercept:
    cost=intercept_error(slope=234,intercept=i,small_data=small_data)
    Cost.append(cost)

# %%
Cost_table=pd.DataFrame({'intercept':intercept,'cost':Cost})
Cost_table.head()
# Out:
#    intercept          cost
# 0       5000  2.779911e+10
# 1       5001  2.779909e+10
# 2       5002  2.779908e+10
# 3       5003  2.779907e+10
# 4       5004  2.779906e+10

# %%
plt.plot(Cost_table.intercept,Cost_table.cost,label='cost function curve')
plt.xlabel('value of intercept')
plt.ylabel('cost')
plt.legend()

# %% [markdown]
# # Gradient Descent

# %%
#STEP 1:initialise parameters
def param_initi(Y):
    
    m=0.1
    c=Y.mean()
    return m,c

# %%
#STEP 2: generate predictions
def generate_predictions(m,c,X):
    predictions=[]
    for x in X:
        pred=(m*x)+c
        predictions.append(pred)
    return predictions

# %%
#STEP 3:calculating cost
def compute_cost(predictions,Y):
    cost=np.sum(((predictions-Y)**2)/len(Y))
    return cost

# %%
#STEP 4:updating parameters
def gradients(predictions,Y,X):
    n=len(Y)
    Gm=2/n*np.sum((predictions-Y)*X)
    Gc=2/n*np.sum((predictions-Y))
    return Gm,Gc

# %%
def update_para(m_old,c_old,Gm_old,Gc_old,alpha):
    m_new=m_old-alpha*Gm_old
    c_new=c_old-alpha*Gc_old
    return m_new,c_new

# %%
#final result pf gradient descent
def result(m,c,X,Y,cost,predictions,i):
#If the gradient desent converged to the optimum value before max_iter
    if i<max_iter -1:
        print("Gradient descent has converged at iteration {}".format(i))
    else:
        print("result after",max_iter,"iteration is:")
#plotting the final result
    plt.figure(figsize=(14,7),dpi=100)
    plt.scatter(X,Y,color='red',label='data points')
    label='final regression line: m={},c={}'.format(str(m), str(c))
    plt.plot(X,predictions,color='green',label=label)
    plt.xlabel("FLAT AREA")
    plt.ylabel("SALE PRICE")
    plt.title("FINAL REGRESSION LINE")
    plt.legend()

# %%
#defining and reshaping the dataset
sale_price=small_data['sale_price'].values.reshape(-1,1)
flat_area=small_data['flat_area'].values.reshape(-1,1)
#declaring parameters
max_iter=1000
cost_old=0
alpha=0.01

#step1: intializing the parameters
m,c=param_initi(sale_price)

#Gradient descent in action
for i in range(0,max_iter):
#step 2:generating predictions
    predictions=generate_predictions(m,c,flat_area)
#step 3:calculating cost
    cost_new=compute_cost(predictions,sale_price)
#checking if GD is converged    
    if abs(cost_new-cost_old) <10**(-7):
        break
#calculating gradients    
    Gm,Gc=gradients(predictions,sale_price,flat_area)
#step 4:updating parameters m and c    
    m,c=update_para(m,c,Gm,Gc,alpha)
    #disply the results after every 20 iterations
    if i%20==0:
        print('After iteration',i,':m=',m,';c=',c,';cost_new',cost_new)
#updating cost_old
    cost_old=cost_new
    
#final results
result(m,c,flat_area,sale_price,cost_new,predictions,i)
# Out:
# After iteration 0 :m= 3499072.307222223 ;c= 465999.44299999997 ;cost_new 64177937552.075005
# After iteration 20 :m= 7.115927055971628e+105 ;c= 2.997778392048355e+102 ;cost_new 2.7417231010181384e+208
# After iteration 40 :m= 1.447154337383132e+205 ;c= 6.096532424296826e+201 ;cost_new inf
# After iteration 60 :m= 2.9430538842431367e+304 ;c= 1.2398417341018387e+301 ;cost_new inf
# After iteration 80 :m= nan ;c= nan ;cost_new nan
# After iteration 100 :m= nan ;c= nan ;cost_new
# <ipython-input-127-b9ae171c0ddd>:3: RuntimeWarning: overflow encountered in square
#   cost=np.sum(((predictions-Y)**2)/len(Y))
# <ipython-input-131-4e6c73753e63>:19: RuntimeWarning: invalid value encountered in double_scalars
#   if abs(cost_new-cost_old) <10**(-7):
# <ipython-input-128-e6bffb1579ed>:4: RuntimeWarning: overflow encountered in multiply
#   Gm=2/n*np.sum((predictions-Y)*X)
# C:\Users\Dell\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
# ...

# %%
#The problem we have is data is not scaled

# %%
#scaling the data using standard scaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sale_price=sc.fit_transform(small_data['sale_price'].values.reshape(-1,1))
flat_area=sc.fit_transform(small_data['flat_area'].values.reshape(-1,1))
#declaring parameters
max_iter=1000
cost_old=0
alpha=0.01

#step1: intializing the parameters
m,c=param_initi(sale_price)

#Gradient descent in action
for i in range(0,max_iter):
#step 2:generating predictions
    predictions=generate_predictions(m,c,flat_area)
#step 3:calculating cost
    cost_new=compute_cost(predictions,sale_price)
#checking if GD is converged    
    if abs(cost_new-cost_old) <10**(-7):
        break
#calculating gradients    
    Gm,Gc=gradients(predictions,sale_price,flat_area)
#step 4:updating parameters m and c    
    m,c=update_para(m,c,Gm,Gc,alpha)
    #disply the results after every 20 iterations
    if i%20==0:
        print('After iteration',i,':m=',m,';c=',c,';cost_new',cost_new)
#updating cost_old
    cost_old=cost_new
    
#final results
result(m,c,flat_area,sale_price,cost_new,predictions,i)
# Out:
# After iteration 0 :m= 0.11316346413633305 ;c= 1.1849780416165836e-16 ;cost_new 0.85836535863667
# After iteration 20 :m= 0.3275595607435688 ;c= 1.240489192847842e-16 ;cost_new 0.6182472245590185
# After iteration 40 :m= 0.4706921039517346 ;c= 1.3248661427193537e-16 ;cost_new 0.5112264752046607
# After iteration 60 :m= 0.5662485308150865 ;c= 1.415904430738617e-16 ;cost_new 0.46352728398628984
# After iteration 80 :m= 0.6300427631414932 ;c= 1.4951003398285442e-16 ;cost_new 0.4422677351921283
# After iteration 100 :m= 0.6726323011945988 ;c= 1.611303683072644e-16 ;cost_new 0.4327923457067555
# After iteration 120 :m= 0.7010654163122192 ;c= 1.666074685620818e-16 ;cost_new 0.42856916078553225
# After iteration 140 :m= 0.7200475906265729 ;c= 1.6660746856208182e-16 ;cost_new 0.4266868855601835
# After iteration 160 :m= 0.7327202415200801 ;c= 1.669405354694694e-16 ;cost_new 0.42584795473189874
# ...

# %% [markdown]
# # IMPLEMENTING LINEAR REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import warnings
warnings.filterwarnings(action='ignore')

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                   0              7
# 1              7242.0           2.0                   0              7
# 2             10000.0           1.0                   0              6
# 3              5000.0           1.0                   0              7
# 4              8080.0           1.0                   0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %% [markdown]
# # SCALING DATA

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Y=data['Sale_Price']
X=sc.fit_transform(data.drop(columns=['Sale_Price']))
X=pd.DataFrame(data=X,columns=data.drop(columns=['Sale_Price']).columns)
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0       -0.398724        -1.447526            -0.979905           -0.228291
# 1       -0.398724         0.175684             0.533718           -0.189858
# 2       -1.474115        -1.447526            -1.426369           -0.123276
# 3        0.676667         1.149611            -0.130534           -0.243983
# 4       -0.398724        -0.148958            -0.435436           -0.169628
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0     -0.915389             -0.30579      -0.563993
# 1      0.936817             -0.30579      -0.563993
# 2     -0.915389             -0.30579      -1.468566
# 3     -0.915389             -0.30579      -0.563993
# 4     -0.915389             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                  -0.734722                -0.658697
# ...

# %% [markdown]
# # Checking and Removing Multicollinearity

# %%
X.corr()
# Out:
#                                            No of Bedrooms  No of Bathrooms  \
# No of Bedrooms                                   1.000000         0.515813
# No of Bathrooms                                  0.515813         1.000000
# Flat Area (in Sqft)                              0.576628         0.754568
# Lot Area (in Sqft)                               0.031692         0.087732
# No of Floors                                     0.175536         0.500776
# No of Times Visited                              0.079575         0.187791
# Overall Grade                                    0.349223         0.635638
# Area of the House from Basement (in Sqft)        0.477549         0.685088
# Basement Area (in Sqft)                          0.303294         0.283798
# Age of House (in Years)                         -0.154113        -0.505954
# Latitude                                        -0.008708         0.024570
# ...

# %%
#pair of independent variables with correlation greater than 0.5
k=X.corr()
z=[[str(i),str(j)] for i in k.columns for j in k.columns if(k.loc[i,j] > abs(0.5))&(i!=j)]
#the var i,j takes every possible combination of ind var's
z,len(z)
# Out:
# ([['No of Bedrooms', 'No of Bathrooms'],
#   ['No of Bedrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Bedrooms'],
#   ['No of Bathrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Floors'],
#   ['No of Bathrooms', 'Overall Grade'],
#   ['No of Bathrooms', 'Area of the House from Basement (in Sqft)'],
#   ['No of Bathrooms', 'Living Area after Renovation (in Sqft)'],
#   ['Flat Area (in Sqft)', 'No of Bedrooms'],
#   ['Flat Area (in Sqft)', 'No of Bathrooms'],
#   ['Flat Area (in Sqft)', 'Overall Grade'],
#   ['Flat Area (in Sqft)', 'Area of the House from Basement (in Sqft)'],
#   ['Flat Area (in Sqft)', 'Living Area after Renovation (in Sqft)'],
#   ['Lot Area (in Sqft)', 'Lot Area after Renovation (in Sqft)'],
#   ['No of Floors', 'No of Bathrooms'],
#   ['No of Floors', 'Area of the House from Basement (in Sqft)'],
#   ['Overall Grade', 'No of Bathrooms'],
#   ['Overall Grade', 'Flat Area (in Sqft)'],
# ...

# %% [markdown]
# 32/2 =16 pairs have unique with correlation >0.5
# dividing by 2 because the combination of i,j and j,i have same corr

# %% [markdown]
# # Calcualting VIF

# %%
#importing variable_inflation factor function from statsmodels
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data=X
#calculating VIF for every column
#i is index of column in data that caluculates vif for....in range of columns
VIF=pd.Series([variance_inflation_factor(vif_data.values,i) for i in range(vif_data.shape[1])],index=vif_data.columns)
VIF
# Out:
# No of Bedrooms                                  1.639470
# No of Bathrooms                                 3.374992
# Flat Area (in Sqft)                          1481.681648
# Lot Area (in Sqft)                              2.108079
# No of Floors                                    2.127787
# No of Times Visited                             1.432385
# Overall Grade                                   2.967448
# Area of the House from Basement (in Sqft)    1205.549115
# Basement Area (in Sqft)                       345.465009
# Age of House (in Years)                         2.629539
# Latitude                                        2.471442
# Longitude                                       1.672691
# Living Area after Renovation (in Sqft)          3.068139
# Lot Area after Renovation (in Sqft)             2.144347
# Years since renovation                          2.788098
# Condition_of_the_House_Excellent               53.578111
# ...

# %%
VIF[VIF==VIF.max()].index[0]
# Out:
# 'Flat Area (in Sqft)'

# %%
def MC_remover(data):
    vif=pd.Series([variance_inflation_factor(data.values,i) for i in range(data.shape[1])],index=data.columns)
    if vif.max()>5:
        print(vif[vif==vif.max()].index[0],'has been removed')
        data=data.drop(columns=(vif[vif==vif.max()].index[0]))
        return data
    else:
        print("NO multicollinearity id present anymore")
        return data

# %% [markdown]
# we give range as 7 because we have 7 ind var's having high VIF,and it runs the function
# 7 times what ever the vif var columns>5 after adjustment at every iteration it removes the column

# %%
for i in range(7):
    vif_data=MC_remover(vif_data)
vif_data.head()
# Out:
# Flat Area (in Sqft) has been removed
# Condition_of_the_House_Fair has been removed
# NO multicollinearity id present anymore
# NO multicollinearity id present anymore
# NO multicollinearity id present anymore
# NO multicollinearity id present anymore
# NO multicollinearity id present anymore
#    No of Bedrooms  No of Bathrooms  Lot Area (in Sqft)  No of Floors  \
# 0       -0.398724        -1.447526           -0.228291     -0.915389
# 1       -0.398724         0.175684           -0.189858      0.936817
# 2       -1.474115        -1.447526           -0.123276     -0.915389
# 3        0.676667         1.149611           -0.243983     -0.915389
# 4       -0.398724        -0.148958           -0.169628     -0.915389
#
#    No of Times Visited  Overall Grade  \
# 0             -0.30579      -0.563993
# 1             -0.30579      -0.563993
# 2             -0.30579      -1.468566
# 3             -0.30579      -0.563993
# 4             -0.30579       0.340581
#
# ...

# %% [markdown]
# # Remaining columns

# %%
VIF=pd.Series([variance_inflation_factor(vif_data.values,i) for i in range(vif_data.shape[1])],index=vif_data.columns)
VIF,len(vif_data.columns)
# Out:
# (No of Bedrooms                               1.638990
#  No of Bathrooms                              3.373805
#  Lot Area (in Sqft)                           2.107495
#  No of Floors                                 2.127703
#  No of Times Visited                          1.432363
#  Overall Grade                                2.956967
#  Area of the House from Basement (in Sqft)    4.580042
#  Basement Area (in Sqft)                      1.974981
#  Age of House (in Years)                      2.626504
#  Latitude                                     2.471343
#  Longitude                                    1.672667
#  Living Area after Renovation (in Sqft)       3.063886
#  Lot Area after Renovation (in Sqft)          2.144068
#  Years since renovation                       2.788064
#  Condition_of_the_House_Excellent             1.206487
#  Condition_of_the_House_Good                  1.251488
#  Condition_of_the_House_Okay                  1.025386
# ...

# %% [markdown]
# # Train/Test

# %%
X=vif_data
y=data['Sale_Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((15126, 28), (6483, 28), (15126,), (6483,))

# %% [markdown]
# # MODEL

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
#we give normalize=True,it will normalize all ind var's such that linear reg will no longer need to find value of intercept
#lr.fit() func implements the gradient descent and complete procedure among the training data
lr.fit(x_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
lr.coef_
# Out:
# array([ -3928.66247639,  12028.44560689,  14967.00497585,   2697.55278605,
#         27220.31313417,  59965.44665815,  80697.80906997,  27729.56715434,
#         27873.90231343,  21397.40341959, -23854.32640243,  17943.26729788,
#         -2896.98542901, -10179.085198  ,  14239.3533334 ,   5095.97603572,
#         -2296.64888137,  14594.33847962,  10761.77007875,  12165.83372082,
#         33842.29544383,  63269.82875283,  81086.08553213,  50718.63947886,
#         73274.09568028,  40153.03595158,  67405.70271285,  22113.74944051])

# %%
predictions=lr.predict(x_test)
lr.score(x_test,y_test)
# Out:
# 0.8461987715586199

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predictions)
# Out:
# 0.8461987715586199

# %% [markdown]
# # 1.Residuals

# %%
residuals=predictions-y_test
residual_table=pd.DataFrame({'residuals':residuals,'predictions':predictions})
residual_table=residual_table.sort_values(by='predictions')

# %%
z=[i for i in range(int(residual_table['predictions'].max()))]
k=[0 for i in range(int(residual_table['predictions'].max()))]

# %%
plt.figure(dpi=100,figsize=(17,7))
plt.scatter(residual_table['predictions'],residual_table['residuals'],color='red',s=2)#s=size of marker
plt.plot(z,k,color='green',linewidth=3,label='regression line')
plt.xlabel('fittedpoints(orderd by predictions')
plt.ylabel('residuals')
plt.title('residual plot')
plt.legend()
plt.show()

# %% [raw]
# *There is a good probability that the residuals are normally distributed
# *The residual plot neither resembls the cone shape nor the pipe shape
# *There is some scope of improvements in the data
# *There have some outliers with positve magnitude in the plot

# %% [markdown]
# # 2.Distribution of errors

# %%
plt.figure(dpi=100,figsize=(14,7))
plt.hist(residual_table['residuals'],color='red',bins=200)
plt.xlabel('residuals')
plt.ylabel('frequency')
plt.title('distribution of residuals')
plt.show()

# %% [markdown]
# *The residuals follow the normal distribution,but some outliers at the right bottom corner ,but its fine

# %% [markdown]
# # Model coefficents

# %%
coefficent_table=pd.DataFrame({'column':x_train.columns,'coefficents':lr.coef_})
coefficent_table=coefficent_table.sort_values(by='coefficents')

# %%
plt.figure(figsize=(8,6),dpi=100)
x=coefficent_table['column']
y=coefficent_table['coefficents']
plt.barh(x,y)
plt.xlabel('coefficents')
plt.ylabel('vairables')
plt.title('Normalized coefficent plot')
plt.show()

# %% [raw]
# *zipcode comes out to be most significent in this model
# i.e location plays a major role in the sale_price of the house and area of house from basement as well
# all othes played a quite significent role in the model
# we have some-ve significance-as the time from the last renovation of the house is increased,the price of the house is decreased
# longitude have -ve significance
# latitude have +ve significance

# %% [markdown]
# # Feature Engineering

# %%
df=pd.read_csv('Datasets\Raw_Housing_Prices3.csv')

# %% [markdown]
# #we are using the data right after clearing missing values and outliers for dep and inpd var's,
# with no transformation in the indep var's are performed

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
sum(df.isnull().sum())
# Out:
# 0

# %% [markdown]
# # Feature Transformation

# %%
plt.figure(figsize=(10,5),dpi=100)
plt.hist(df['Flat Area (in Sqft)'],bins=150,color='red')
plt.xlabel('Flat area')
plt.ylabel('Frequency')
plt.title('Distribution of Flat area')
plt.show()

# %% [markdown]
# we can able to see that the plot is right skewed and need to do some feature transformation(i.e is nth root of log)

# %%
def log_transform(sample_data):
    return np.log(sample_data)

# %%
df['Transformed flat area']=df['Flat Area (in Sqft)'].map(log_transform)

# %%
plt.figure(figsize=(10,5),dpi=100)
plt.hist(df['Transformed flat area'],bins=150,color='red')
plt.xlabel('Flat area')
plt.ylabel('Frequency')
plt.title('Distribution of Flat area')
plt.show()

# %% [markdown]
# now we got normal distribution of variables,this might inc the value of R**2

# %% [markdown]
# # Dummy/One hot encoding

# %%
df['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
dummy_var1 = pd.get_dummies( df['Condition of the House'], drop_first = True, prefix = 'Condition')
dummy_var1.head()
# Out:
#    Condition_Excellent  Condition_Fair  Condition_Good  Condition_Okay
# 0                    0               1               0               0
# 1                    0               1               0               0
# 2                    0               1               0               0
# 3                    1               0               0               0
# 4                    0               1               0               0

# %% [markdown]
# # Label Encoding

# %%
label_encoding=df['Condition of the House']
label_encoding.value_counts()
# Out:
# Fair         14028
# Good          5678
# Excellent     1701
# Okay           172
# Bad             30
# Name: Condition of the House, dtype: int64

# %%
label_encoding=label_encoding.map({'Bad':1,'Okay':2,'Fair':3,'Good':4,'Excellent':5})
label_encoding.value_counts()
# Out:
# 3    14028
# 4     5678
# 5     1701
# 2      172
# 1       30
# Name: Condition of the House, dtype: int64

# %% [markdown]
# # Binning(sparse categories)

# %%
df['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
df['Condition of the House'].value_counts()
# Out:
# Fair         14028
# Good          5678
# Excellent     1701
# Okay           172
# Bad             30
# Name: Condition of the House, dtype: int64

# %%
mean = []

for i in df['Condition of the House'].unique():
    mean.append(df['Sale Price'][df['Condition of the House'] == i].mean())

# %%
plt.figure( figsize = (7,7), dpi = 100)

plt.bar( df['Condition of the House'].unique(), mean)
plt.xlabel('Condition of the House')
plt.ylabel("mean sale Prie")
# Out:
# Text(0, 0.5, 'mean sale Prie')

# %% [markdown]
# from the plot the avg sale price for bad,okay and fair,good are redundent or same,so we can make this into 3 class variables

# %%
mapping = {'Excellent':'Excellent',
           'Fair':'Good',
           'Good':'Good',
           'Okay':'Okay',
           'Bad':'Okay'}
df['Condition of the House'] = df['Condition of the House'].map(mapping)

# %%
mean = []

for i in df['Condition of the House'].unique():
    mean.append(df['Sale Price'][df['Condition of the House'] == i].mean())

# %%
plt.figure( figsize = (7,7), dpi = 100)

plt.bar( df['Condition of the House'].unique(), mean)
plt.xlabel('Condition of the House')
plt.ylabel("mean sale Prie")
# Out:
# Text(0, 0.5, 'mean sale Prie')

# %% [markdown]
# # Binning(continous categories)

# %%
len(data['Age of House (in Years)'].unique())
# Out:
# 116

# %%
data['Age of House (in Years)'].max()
# Out:
# 118

# %%
data['Age of House (in Years)'].min()
# Out:
# 3

# %%
def age_of_house(x):
    if x < 10:
        x = 'new'
    elif x < 50:
        x = 'old'
    else:
        x = 'very old'
    return x

# %%
cat_house_age = df['Age of House (in Years)'].map(age_of_house)
cat_house_age.unique()
# Out:
# array(['very old', 'old', 'new'], dtype=object)

# %% [markdown]
# # Feature generation

# %%
df['Date House was Sold'].head()
# Out:
# 0     14 October 2017
# 1    14 December 2017
# 2    15 February 2016
# 3    14 December 2017
# 4    15 February 2016
# Name: Date House was Sold, dtype: object

# %%
time = pd.DatetimeIndex(df['Date House was Sold'])
df['year_sold'] = time.year
df["month_sold"] = time.month
#df['weekday_sold'] =time.weekday_name
df['weekday_sold'] =time.day_name()
df['date_sold'] = time.days_in_month

df[['year_sold','month_sold','date_sold']].head()
# Out:
#    year_sold  month_sold  date_sold
# 0       2017          10         31
# 1       2017          12         31
# 2       2016           2         29
# 3       2017          12         31
# 4       2016           2         29

# %%
month_sale = pd.pivot_table(df, values = 'Sale Price',
               columns = 'month_sold',
                aggfunc = 'mean')

month_sale
# Out:
# month_sold             1              2              3              4   \
# Sale Price  494549.626789  485457.269015  515501.697439  533078.767817
#
# month_sold             5              6              7              8   \
# Sale Price  518714.583092  527367.035337  519160.693351  507810.789691
#
# month_sold             9              10             11             12
# Sale Price  502577.903044  508442.986155  495134.871722  497170.721278

# %%
plt.figure( figsize = (5,5), dpi = 120)
plt.bar(month_sale.columns, month_sale.iloc[0])
plt.xlabel("month")
plt.ylabel('mean_sale')
# Out:
# Text(0, 0.5, 'mean_sale')

# %% [markdown]
# # combination of features

# %%
def luxury_home(row):
    count = 0
    if row[0] =='Yes':
        count = count+1
    if row[1] in ['Excellent','Good']:
        count = count+1
    if row[2] >= 8:
        count = count+1  
    if count >= 2 :
        return 'Yes'
    else:
        return "No"
df['luxury_home'] = df[['Waterfront View','Condition of the House','Overall Grade']].apply(luxury_home, axis = 1)

df['luxury_home'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['luxury_home'].value_counts()
# Out:
# No     11285
# Yes    10324
# Name: luxury_home, dtype: int64

# %%
luxury = df.pivot_table(values = "Sale Price", columns = 'luxury_home', aggfunc = 'mean' )
luxury
# Out:
# luxury_home            No            Yes
# Sale Price   380385.64475  655067.166021

# %%
plt.figure(figsize = (7,7), dpi = 100)
plt.bar(luxury.columns, luxury.iloc[0])
plt.xlabel('Luxury home?')
plt.ylabel(" Mean Sale Price")
# Out:
# Text(0, 0.5, ' Mean Sale Price')

# %% [markdown]
# # DIMENSINALITY REDUCTION

# %%
da=pd.read_csv('Datasets\dm_houseprices.csv')

# %%
da.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                  NaN              7
# 1              7242.0           2.0                  NaN              7
# 2             10000.0           1.0                  NaN              6
# 3              5000.0           1.0                  NaN              7
# 4              8080.0           1.0                  NaN              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %%
da.shape
# Out:
# (21609, 31)

# %%
da.isnull().sum()
# Out:
# Sale_Price                                       0
# No of Bedrooms                                   0
# No of Bathrooms                                  0
# Flat Area (in Sqft)                              0
# Lot Area (in Sqft)                               0
# No of Floors                                     0
# No of Times Visited                          19485
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        0
# Basement Area (in Sqft)                      13123
# Age of House (in Years)                          0
# Latitude                                         0
# Longitude                                        0
# Living Area after Renovation (in Sqft)           0
# Lot Area after Renovation (in Sqft)              0
# Years Since Renovation                       20695
# Condition_of_the_House_Excellent                 0
# Condition_of_the_House_Fair                      0
# ...

# %%
len(da)
# Out:
# 21609

# %% [markdown]
# # Missing value ratio

# %%
for i in da.columns:
    tmp=da[i].isnull().sum()/len(da)
    if tmp>0.70:
        print("Removing columns:"+i+" with missing value ratio of",tmp)
        da.drop(columns=[i])
# Out:
# Removing columns:No of Times Visited with missing value ratio of 0.9017076218242399
# Removing columns:Years Since Renovation with missing value ratio of 0.9577028090147623

# %% [markdown]
# # Low Variance

# %%
da1=pd.read_csv('Datasets\Raw_Housing_Prices3.csv')

# %%
da1.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
da1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
numerical_data=da1.drop(columns=['ID','Date House was Sold','Waterfront View','Condition of the House',
                                 'No of Times Visited','Overall Grade','Zipcode','Sale Price'])
numerical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   No of Bedrooms                             21609 non-null  int64
#  1   No of Bathrooms                            21609 non-null  float64
#  2   Flat Area (in Sqft)                        21609 non-null  float64
#  3   Lot Area (in Sqft)                         21609 non-null  float64
#  4   No of Floors                               21609 non-null  float64
#  5   Area of the House from Basement (in Sqft)  21609 non-null  float64
#  6   Basement Area (in Sqft)                    21609 non-null  int64
#  7   Age of House (in Years)                    21609 non-null  int64
#  8   Renovated Year                             21609 non-null  int64
#  9   Latitude                                   21609 non-null  float64
# ...

# %%
from sklearn.preprocessing import Normalizer
norm=Normalizer()
norm_data=norm.fit_transform(numerical_data)
norm_data=pd.DataFrame(norm_data,columns=numerical_data.columns)
norm_data.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0        0.000363         0.000121             0.142628            0.682924
# 1        0.000264         0.000198             0.226174            0.637335
# 2        0.000152         0.000076             0.058440            0.758961
# 3        0.000527         0.000395             0.258159            0.658569
# 4        0.000263         0.000175             0.147072            0.707346
#
#    No of Floors  Area of the House from Basement (in Sqft)  \
# 0      0.000121                                   0.142628
# 1      0.000176                                   0.190972
# 2      0.000076                                   0.058440
# 3      0.000132                                   0.138299
# 4      0.000088                                   0.147072
#
#    Basement Area (in Sqft)  Age of House (in Years)  Renovated Year  Latitude  \
# ...

# %%
tmp=norm_data.var()
tmp
# Out:
# No of Bedrooms                               4.071117e-08
# No of Bathrooms                              2.802492e-08
# Flat Area (in Sqft)                          1.231500e-02
# Lot Area (in Sqft)                           1.351803e-02
# No of Floors                                 3.008524e-08
# Area of the House from Basement (in Sqft)    1.010140e-02
# Basement Area (in Sqft)                      1.648493e-03
# Age of House (in Years)                      2.002344e-05
# Renovated Year                               1.684740e-03
# Latitude                                     1.077875e-05
# Longitude                                    7.109191e-05
# Living Area after Renovation (in Sqft)       1.079222e-02
# Lot Area after Renovation (in Sqft)          1.250016e-02
# dtype: float64

# %%
T=1e-04
for i in tmp:
    if i<T:
        norm_data.drop(columns=[tmp[tmp==i].index[0]],inplace=True)
norm_data.var()
# Out:
# Flat Area (in Sqft)                          0.012315
# Lot Area (in Sqft)                           0.013518
# Area of the House from Basement (in Sqft)    0.010101
# Basement Area (in Sqft)                      0.001648
# Renovated Year                               0.001685
# Living Area after Renovation (in Sqft)       0.010792
# Lot Area after Renovation (in Sqft)          0.012500
# dtype: float64

# %% [markdown]
# # Forward Selection

# %% [markdown]
# we are using forward selection right after the linear reg model

# %%
def adj_r2(data_x,data_y,predictions):
    from sklearn.metrics import r2_score
    R=r2_score(data_y,predictions)
    n=len(data_y)
    m=len(data_x.columns)
    adj_r2=1-((n-1)*(1-R))/(n-m-1)
    return adj_r2

# %%
adj_r2(x_test,y_test,predictions)
# Out:
# 0.8455315211098503

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predictions)
# Out:
# 0.8461987715586199

# %% [markdown]
# Here adj r2 < r2 marginally smaller,from this we can say that there are some features which are not adding value to final model

# %%
#returns adj r2 corresponding to the model
def return_r2(X,Y,model):
    model.fit(X,Y)
    pred=model.predict(X)
    r2=adj_r2(X,Y,pred)
    return r2

# %%
def forward_selection(model,X,Y,max_features):
    '''
    max_features:select best features up to max features value
    returns:
    RMAX:adj r2 of final model
    history:list of RMAX at every new ind var added to the model
    x[f_col]: best features upto max_features
    '''
    f_col=[] #stores the var being selected at every step of forwaed selection
    history=[]
    for i in range(max_features):
        f_col.append('blank')
        tmp=f_col[:]
        Rmax=-1 # tracks adding wich var produces max adj r2
        for var in X.columns:
            tmp[-1]=var #for any given iteration last element of tmp is assinged as a new column to track
            r2=return_r2(X[tmp],Y,model)
            if r2>=Rmax:
                Rmax=r2
                f_col[-1]=var
                elim=var
        print('selected',f_col[-1],'with new r2=',Rmax)
        history.append(Rmax)
    return Rmax,history,X[f_col]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
score,history,sel_data=forward_selection(lr,x_train,y_train,5)
# Out:
# selected Overall Grade with new r2= 0.46330521459442986
# selected Latitude with new r2= 0.5719394706222798
# selected Living Area after Renovation (in Sqft) with new r2= 0.6259771955140173
# selected Age of House (in Years) with new r2= 0.6707670543852546
# selected No of Bathrooms with new r2= 0.7003064994858662

# %%
sel_data.columns
# Out:
# Index(['Overall Grade', 'Latitude', 'Living Area after Renovation (in Sqft)',
#        'Age of House (in Years)', 'No of Bathrooms'],
#       dtype='object')

# %%
score
# Out:
# 0.7003064994858662

# %% [markdown]
# # Backward Elimination

# %%
def backward_elimination(model,X,Y,min_features):#specify no of features need to keep
    elim_data=X[:] #copy all the columns of x_train 
    r2_history=[] #to keep track adj r2 score hwen ever a feature is eliminated
    base_r2=return_r2(elim_data,Y,model)
    print('base_r2 is:',base_r2)
    for i in range(X.shape[1] - min_features):
        difference = -100
        
        for var in elim_data.columns:
            tmp = elim_data.drop(columns = [var])
            r2 = return_r2(tmp, Y, model)
            
            if (r2 - base_r2) > difference:
                difference = r2 - base_r2
                eliminate = var
                new_r2 = r2
        
        elim_data.drop(columns = [eliminate], inplace = True)
        r2_history.append(new_r2)
        
        print(eliminate,"Eliminated : New adj_r2 = ",new_r2,)
        base_r2 = new_r2
        
        return base_r2, r2_history, elim_data

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
score,history,survived_data=backward_elimination(lr,x_train,y_train,1)
# Out:
# base_r2 is: 0.8409462124647622
# No of Floors Eliminated : New adj_r2 =  0.8409014194514582

# %%
history
# Out:
# [0.8409014194514582]

# %%
plt.figure(figsize = (5,5), dpi = 150)
plt.plot(range(len(history),0,-1), history, color = 'red')
plt.xlabel('remaining features')
plt.ylabel('adj-R2 Score')
#plt.yticks([z/100 for z in range()])
plt.title('Backward Elimination')
# Out:
# Text(0.5, 1.0, 'Backward Elimination')
